# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
db = pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-29387d9c7b16> in <module>()
# ----> 1 db = pd.read_clipboard()
#
# /usr/lib/python3/dist-packages/pandas/io/clipboard.py in read_clipboard(**kwargs)
#      49         kwargs['sep'] = '\s+'
#      50
# ---> 51     return read_table(StringIO(text), **kwargs)
#      52
#      53
#
# ...

# %%
db
# Out:
#                                              Materia        Fecha   \
# 0                        (MA046) ANÁLISIS MATEMÁTICO   22/04/2013
# 1                                    (MA045) ÁLGEBRA   22/04/2013
# 2        (IF002) EXPRESIÓN DE PROBLEMAS Y ALGORITMOS   24/07/2013
# 3                   (IF001) ELEMENTOS DE INFORMÁTICA   01/08/2013
# 4               (IF003) ALGORÍTMICA Y PROGRAMACIÓN I   03/12/2013
# 5   (MA008) ELEMENTOS DE LOGICA Y MATEMATICA DISCR...  05/12/2013
# 6                     (FA007) ACREDITACION DE IDIOMA   06/12/2013
# 7               (IF005) ARQUITECTURA DE COMPUTADORAS   10/07/2014
# 8                  (IF004) SISTEMAS Y ORGANIZACIONES   10/07/2014
# 9              (IF006) ALGORÍTMICA Y PROGRAMACIÓN II   07/08/2014
# 10          (IF008) PROGRAMACIÓN ORIENTADA A OBJETOS   09/12/2014
# 11                       (IF011) SISTEMAS OPERATIVOS   30/07/2015
# 12                          (IF007) BASES DE DATOS I   03/08/2015
# ...

# %%
23/33
# Out:
# 0.696969696969697
