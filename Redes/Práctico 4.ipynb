# %% [markdown]
# Trabajo Práctico N° 4: Redes Locales
# ====================================
#
# ### 1. ¿Qué aspectos trata la subcapa MAC (Medium Access Control)?
#
# * Parte inferior de la capa de enlace de datos
#
# * La capa de control de acceso al medio comprende protocolos para determinar quién sigue en el uso de un canal multiacceso, o canal de comunicación compartido en redes de difusión.
#
# * Mayoría de LANs y redes de satélites emplean canal multiacceso, ó de acceso aleatorio. Distinto de WANs que emplean enlaces PaP
#
# ### 2. Enunciar los Protocolos de Acceso Múltiple sin detección de Portadora ¿cuál es más eficiente y porqué?
#
# Aloha y Aloha Ranurado.
#
# Aloha ranurado es más eficiente. Al dividir el tiempo en intervalos y sincronizar los nodos se evita que se encadenen colisiones, el efecto de una colisión esta limitado a un intervalo concreto.
#
# ### 3. ¿Qué mejora introducen los protocolos CSMA? ¿Y el CSMA/CD?
#
# Antes de transmitir verifican que nadie este transmitiendo. CSMA/CD introduce detección de colisiones (deja de transmitir trama en cuanto detecta una colisión).
#
# ### 4. Una gran cantidad de usuarios de un canal Aloha ranurado generan 50 mensajes/segundo, incluyendo originales y retransmitidos. El tiempo del slot o ranura esta fijado en 40ms. Determinar el % de mensajes que llegará a destino sin necesidad de que sean retransmitidos.
#
# $$ G = 50\text{ msg}/s * 0.04s = 2\text{msg} $$
#
# $$ P_0 = e^{-g} \approx 0.1353 $$
#
# Aproximadamente el $ 13.5\% $ de los mensajes llegarán a destino sin ser retransmitidos.
#
# ### 5. Un grupo de N estaciones comparten un canal Aloha puro de 56Kbps. Cada estación entrega un mensaje de 1000 bits cada 100 segundos. ¿Cuál es el máximo valor de N?
#
# $$ Rb_{\text{real}} = Rb * \text{eficiencia} $$
#
# $$ 56000 b/s * 0.18 = 10080 b/s $$
#
# $$ Rb_{\text{estación}} = 1000b / 100s = 10b/s $$
#
# $$ N = Rb_{\text{real}} / Rb_{\text{estación}} $$
#
# $$ N = 10080 / 10 = 1008 \text{ estaciones} $$
#
# ### 6. Considerar la construcción de una red CSMA/CD que opera a 1Gbps a través de un cable de 1km de longitud sin repetidores. La velocidad de la señal en el cable es de 200.000km/s. ¿Cuál es el tamaño mínimo de la trama?
#
# $$ \tau = 5*10^{-6} s $$
#
# $$ T_t = \tau $$
#
# $$ L_t = Rb * T_t $$
#
# $$ L_t \ge 5*10^{-6} s * 10^9 b/s $$
#
# $$ L_t \ge 5000b $$
#
# ### 7. Se considera construir una red CSMA/CD de 3Gbps sobre un cable de 20Km con 5 repetidoras que poseen un retardo propio de 2&mu;s cada una. La propagación de la señal en el cable es de 200.000km/s. ¿Cuál debe ser el tamaño mínimo de trama en bytes?
#
# $$ \tau = 0.0001s + 0.00001s = 0.00011s $$
#
# $$ L_t \ge 0.00011s * 3*10^9b/s $$
#
# $$ L_t \ge 33000b $$
#
# $$ L_t \ge 41250 \text{ bytes} $$
#
# ### 8. Enunciar 2 protocolos libres de colisiones.
#
# * Protocolo de Mapa de Bits
# * Protocolo de Conteo Descendente Binario
#
# ### 9. ¿Qué tipo de LAN describe la Norma IEEE 802.3?
#
# Ethernet (CSMA persistente-1)
#
# ### 10. La Norma IEEE 802.3 especifica los niveles OSI:
#
# d. 1 y mitad del 2
#
# La capa física y la subcapa de control de acceso al medio.
#
# ### 11. ¿Qué significa tipo de cableado 10Base-T empleado en Redes Ethernet? ¿Qué cableado se emplea en 10Base2 y 10Base-F?
#
# * **10Base-T:** Par trenzado (twisted pair). Las estaciones se conectan con par trenzado al hub que facilita el mantenimiento de los cables. Longitud máxima de cable de 100 metros.
# * **10Base2:** Coaxil delgado. 200 metros por segmento, 30 nodos por segmento.
# * **10Base-F:** Fibra óptica. 2000 metros por segmento, 1024 nodos por segmento.
#
# ### 12. ¿Para qué se emplea codificación Manchester en 802.3?
#
# Permite distinguir bit 0 respecto a transmisor inactivo. Los receptores pueden determinar sin ambiguedades inicio, final y mitad de cada bit.
#
# ### 13. ¿Cuál es la tasa de baudios de la LAN 802.3 de 10Mbps estándar?
#
# Codificación Manchester. 2 baudios por bit (High-Low)
#
# ### 14. ¿Cuál es el objetivo del Campo de Relleno (0-46 bytes) en la trama 802.3? ¿Para qué se utiliza el campo de preámbulo en tramas MAC 802.3 y 802.4?
#
# * Debe haber un mínimo de 64 bytes desde Dir. Destino hasta Suma Comprobación para diferenciar tramas válidas de bits perdidos por colisión. Datos + Relleno $\ge$ 46 bytes.
#
# * Se rellena con el patrón 10101010 x 7. Onda cuadrada de 10Mhz en código Manchester durante 5.6&mu;s para que Rx se sincronice con reloj de Tx.
#
# ### 15. ¿Por qué las tramas MAC 802.3 no tienen campo de control? ¿Por qué si los tienen las de 802.4 y 802.5?
#
# Ethernet no tiene tramas de control. Token Bus y Token Ring usan el campo para diferenciar tramas de datos de tramas de control.
#
# ### 16. Indicar qué problemas pueden presentarse en 802.5 con respecto al mantenimiento de anillos y del token.
#
# ### 17. ¿Qué mecanismo de espera emplea LAN 802.3 tras $i$ colisiones?
#
# Algoritmo de Retroceso Exponencial Binario
#
# ### 18. ¿Qué tipo de LAN describe la Norma 802.5? ¿Qué influencia tiene el uso de un centro de cableado o alambrado?
#
# Token Ring. Facilita el mantenimiento, además aporta confiabilidad al evitar que se corte el servicio de la red ante el fallo de una única conexión.
#
# ### 19. Enunciar dos ventajas y desventajas de los 3 tipos de LANs vistos
#
# #### 802.3 Ethernet
# * **Ventajas**
#     * Protocolo sencillo, cable pasivo, sin modems
#     * Retardo con baja carga es casi cero
# * **Desventajas**
#     * Trama mínima de 64 bytes
#     * No determinístico
#
# #### 802.4 Token Bus
# * **Ventajas**
#     * Más determinístico que 802.3
#     * Puede manejar tramas mínimas cortas
# * **Desventajas**
#     * Protocolo complicado
#     * Retardo grande cuando la carga es baja (se debe esperar el token incluso aunque no haya tráfico)
#
# #### 802.5 Token Ring
# * **Ventajas**
#     * Conexiones PaP, sencillas y digitales
#     * El uso de centros de cableado permite detectar y eliminar fallas de cableado automáticamente
# * **Desventajas**
#     * Función de Monitor centralizada
#     * Retardo a muy baja carga (por paso del token)
#
# ### 20. En LANs la subcapa LLC puede implementar control de errores y flujo solamente sobre los protocolos.
#
# d. Cualquiera
#
# LLC esconde diferencias entre las distintas redes 802.
#
# ### 21. ¿Qué pasa si en Token Ring una estación acepta el token y después se cae? ¿Cómo maneja esto el protocolo?
#
# Vence temporizador, mete otro token.
#
# ### 22. ¿Por qué en Token Ring el emisor es el que remueve la trama del anillo y no el receptor?
#
# ### 23. ¿En LANs, cuáles de los siguientes modos de acceso al medio son No Determinísticos?
#
# ### 24. ¿Qué es un HUB? ¿Qué es un LAN Switch? ¿Qué es un Bridge? ¿Qué tipo de solución aporta cada uno?
#
# ### 25. ¿Qué tipos de LANs de alta velocidad conoce?
#
# ### 26. Se dice que CSMA/CD es inapropiado para aplicaciones en tiempo real porque el peor caso de intervalo de retransmisión no es limitado ¿Bajo qué circunstancias puede usarse el mismo argumento para un anillo con Token Bus? ¿Bajo qué circunstancias tiene entonces un peor caso conocido? Asumir que el número de estaciones del anillo es fijo y conocido.
#
# ### 27. Con una tasa de transmisión de 5Mbps y una velocidad de propagación de 200m/&mu;s, ¿a cuántos metros de cable equivale el retardo de un bit de una interfase Token Ring?
#
# $$ 200m/\mu s = 200000km/s $$
#
# $$ L_t = Rb * T_t $$
#
# $$ \dfrac{L_t}{Rb} = T_t $$
#
# $$ \dfrac{1b}{5000000b/s} = 2 * 10^{-7}s $$
#
# $$ 2 * 10^{-7}s * 2*10^9m/s = 40m $$
#
# 40 metros
#
# ### 28. Un Token Ring de 4 Mbps tiene un valor de Temporización de 10ms para la retención del Token. ¿De qué tamaño es la trama más grande que puede enviarse en este anillo?
#
# $$ \dfrac{4*10^6 * 10^{-2}}{8\text{ bits/byte}} = 5\text{ kbytes} $$
#
# ### 29 En un sistema que emplea una interfase Token Ring de 64 Mbps, con un temporizador de 5ms para retención del Token ¿Cuál deberá ser el tamaño máximo de trama en bytes que se puede enviar?
#
# $$ \dfrac{64*10^6 * 5*10^{-3}}{8\text{ bits/byte}} = 40\text{ kbytes} $$

# %%
4000000 * 0.01
(64000000 * 5/1000) / 8
# Out:
# 40000.0
