# %%
import numpy as np

import matplotlib.pyplot as plt

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %matplotlib inline

# %%
def func(x, y):
    return x ** 2 + y

x = y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)

z = func(x, y)

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.gca(projection='3d')

ax.plot_wireframe(x, y, z, alpha=0.5, rstride=5, cstride=5, cmap=cm.BuGn)
#ax.plot_wireframe(x, y, z2, alpha=0.4, rstride=5, cstride=5, cmap=cm.BuPu)

#cset = ax.contour(x, y, z, zdir='x', cmap=cm.Blues)
#cset = ax.contour(x, y, z, zdir='y', cmap=cm.Blues)
#cset = ax.contour(x, y, z, zdir='z', cmap=cm.Blues)

plt.show()
